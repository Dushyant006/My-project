# %%
student_name = input("Enter Student Name: ")
student_class = input("Enter Class: ")

print("\nEnter marks for 5 subjects (out of 100):")
marks = []
for i in range(1, 6):
    mark = float(input(f"Subject {i} Marks: "))
    marks.append(mark)

total_marks = sum(marks)
percentage = (total_marks / 500) * 100

print("RESULT")
print(f"Name       : {student_name}")
print(f"Class      : {student_class}")
print(f"Total Marks: {total_marks} / 500")
print(f"Percentage : {percentage:.2f}%")
# Out:
# Enter marks for 5 subjects (out of 100):
# RESULT
# Name       : yash
# Class      : 12th
# Total Marks: 454.0 / 500
# Percentage : 90.80%

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

combined_str = str1 + " " + str2
print(f"\nCombined String: '{combined_str}'\n")

print(f"1. lower()      : {combined_str.lower()}")
print(f"2. upper()      : {combined_str.upper()}")
print(f"3. title()      : {combined_str.title()}")
print(f"4. swapcase()   : {combined_str.swapcase()}")
print(f"5. capitalize() : {combined_str.capitalize()}")
print(f"6. casefold()   : {combined_str.casefold()}")
print(f"7. center(30)   : '{combined_str.center(30)}'")
print(f"8. count('e')   : {combined_str.count('e')}")
print(f"9. endswith('!') : {combined_str.endswith('!')}")
print(f"10. find('a')   : {combined_str.find('a')}")
print(f"11. isalnum()   : {combined_str.isalnum()}")
print(f"12. isdigit()   : {combined_str.isdigit()}")
print(f"13. isnumeric() : {combined_str.isnumeric()}")
print(f"14. isspace()   : {combined_str.isspace()}")

print(f"15. replace()   : {combined_str.replace(' ', '-')}")
# Out:
# Combined String: 'this is python'
#
# 1. lower()      : this is python
# 2. upper()      : THIS IS PYTHON
# 3. title()      : This Is Python
# 4. swapcase()   : THIS IS PYTHON
# 5. capitalize() : This is python
# 6. casefold()   : this is python
# 7. center(30)   : '        this is python        '
# 8. count('e')   : 0
# 9. endswith('!') : False
# 10. find('a')   : -1
# 11. isalnum()   : False
# 12. isdigit()   : False
# 13. isnumeric() : False
# 14. isspace()   : False
# 15. replace()   : this-is-python

# %%
percentage = float(input("Enter the student's percentage: "))

if percentage >= 60:
    grade = 'A'
elif percentage >= 50:
    grade = 'B'
elif percentage >= 40:
    grade = 'C'
elif percentage >= 33:
    grade = 'D'
else:
    grade = 'Fail'

print(f"Percentage: {percentage:.2f}%")
print(f"Grade     : {grade}")
# Out:
# Percentage: 90.00%
# Grade     : A
